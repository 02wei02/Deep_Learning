# %% [markdown]
# # Just an example.You can alter sample code anywhere.

# %% [markdown]
# ## mount your google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# You need to modify this part to the directory where your code is located
# %cd "/content/drive/MyDrive/DL_Lab1/"
# Out:
# /content/drive/MyDrive/DL_Lab1

# %% [markdown]
# ## Import packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import model

# %%
#Fix the random seed
np.random.seed(0)

# %% [markdown]
# ## Load the data and label

# %%
import numpy as np

# Load the data
train_load = np.loadtxt('./data/kmnist-train.csv', delimiter=',', dtype="int")
test_load = np.loadtxt('./data/kmnist-test.csv', delimiter=',', dtype="int")

# Separate the features and labels
train_data = train_load[:, 1:]
train_label = train_load[:, 0]
test_data = test_load

# # Perform normalization (scale pixel values to the range [0, 1])
# train_data = train_data / 255.0
# test_data = test_data / 255.0

# # Invert colors (optional)
# # If the original KMNIST dataset has white background and black digits, inverting will make black background and white digits.
# # If you want to keep it in the original form, skip the next step.
# train_data = 1 - train_data
# test_data = 1 - test_data

# Check the shapes
print("Shape of train_data: {}".format(train_data.shape))
print("Shape of train_label: {}".format(train_label.shape))
print("Shape of test_data: {}".format(test_data.shape))
# Out:
# Shape of train_data: (60000, 784)
# Shape of train_label: (60000,)
# Shape of test_data: (10000, 784)

# %% [markdown]
# ## Show the training data

# %%
# uncomment if you want to show the training data
# plt.figure(figsize=(20, 20))
# for index in range(10):
#    image = train_data[index+1000].reshape(28,28)
#    plt.subplot(2, 5, index+1)
#    plt.imshow(image)
# plt.show()

# %%
train_image_num = train_data.shape[0]
test_image_num = test_data.shape[0]
train_data = train_data.astype(np.float32)
test_data = test_data.astype(np.float32)

print("train_image_num  is : {}".format(train_image_num))
print("test_image_num   is : {}".format(test_image_num))
# Out:
# train_image_num  is : 60000
# test_image_num   is : 10000

# %% [markdown]
# ## Validation image number

# %%
val_image_num=10000

# %% [markdown]
# ## Convert the training labels to one hot vector

# %%
label_temp = np.zeros((train_image_num, 10), dtype = np.float32)
for i in range(train_image_num):
    label_temp[i][train_label[i]] = 1
train_label_onehot = np.copy(label_temp)
print("One-hot training labels shape:",train_label_onehot.shape)
# Out:
# One-hot training labels shape: (60000, 10)

# %% [markdown]
# ## Hyperparameters

# %%
EPOCH = 40
Batch_size =  25 # 10000 should be divisible by batch_size
# Learning_rate = 0.1

# learning rate is 0.3
Learning_rate = 0.1

# %% [markdown]
# ## Training

# %%
# please make sure you have place layer.py & network.py in 'model' folder
net = model.Network()

train_batch_num = (train_image_num  -  val_image_num  )//Batch_size
val_batch_num = (val_image_num)//Batch_size

for epoch in range(1, EPOCH+1):
    train_hit = 0
    val_hit = 0
    total_train_loss = 0.0
    total_val_loss = 0.0
    for it in range(train_batch_num):
        pred, train_loss = net.forward(train_data[it*Batch_size:(it+1)*Batch_size], train_label_onehot[it*Batch_size:(it+1)*Batch_size])
        pred_index = np.argmax(pred, axis=1)
        train_hit += (pred_index==train_label[it*Batch_size:(it+1)*Batch_size]).sum()
        total_train_loss += train_loss

        net.backward()
        net.update(Learning_rate)

    for titt in range(val_batch_num):
        tit=train_batch_num+titt
        pred, val_loss = net.forward(train_data[tit*Batch_size:(tit+1)*Batch_size], train_label_onehot[tit*Batch_size:(tit+1)*Batch_size])
        pred_index = np.argmax(pred, axis=1)
        val_hit += (pred_index==train_label[tit*Batch_size:(tit+1)*Batch_size]).sum()
        total_val_loss += val_loss

    print('Task1  | Epoch:%3d'%epoch, ' |Train Loss:%8.4f'%(total_train_loss/train_batch_num), ' |Train Acc:%3.4f'%(train_hit/(train_image_num-val_image_num)*100.0)
          , ' |Val Loss:%8.4f'%(total_val_loss/val_batch_num), ' |Val Acc:%3.4f'%(val_hit/val_image_num*100.0))
# Out:
# Task1  | Epoch:  1  |Train Loss:  0.4690  |Train Acc:85.4360  |Val Loss:  0.2781  |Val Acc:91.3600
# Task1  | Epoch:  2  |Train Loss:  0.1949  |Train Acc:94.1620  |Val Loss:  0.2059  |Val Acc:93.8400
# Task1  | Epoch:  3  |Train Loss:  0.1188  |Train Acc:96.7040  |Val Loss:  0.1744  |Val Acc:94.6700
# Task1  | Epoch:  4  |Train Loss:  0.0744  |Train Acc:98.1940  |Val Loss:  0.1592  |Val Acc:95.2900
# Task1  | Epoch:  5  |Train Loss:  0.0460  |Train Acc:99.0880  |Val Loss:  0.1520  |Val Acc:95.5900
# Task1  | Epoch:  6  |Train Loss:  0.0280  |Train Acc:99.6020  |Val Loss:  0.1477  |Val Acc:95.7700
# Task1  | Epoch:  7  |Train Loss:  0.0176  |Train Acc:99.8360  |Val Loss:  0.1462  |Val Acc:95.9500
# Task1  | Epoch:  8  |Train Loss:  0.0114  |Train Acc:99.9220  |Val Loss:  0.1456  |Val Acc:96.1900
# Task1  | Epoch:  9  |Train Loss:  0.0078  |Train Acc:99.9760  |Val Loss:  0.1460  |Val Acc:96.2400
# Task1  | Epoch: 10  |Train Loss:  0.0057  |Train Acc:99.9920  |Val Loss:  0.1464  |Val Acc:96.3600
# Task1  | Epoch: 11  |Train Loss:  0.0044  |Train Acc:99.9980  |Val Loss:  0.1474  |Val Acc:96.4000
# Task1  | Epoch: 12  |Train Loss:  0.0036  |Train Acc:100.0000  |Val Loss:  0.1486  |Val Acc:96.4400
# Task1  | Epoch: 13  |Train Loss:  0.0030  |Train Acc:100.0000  |Val Loss:  0.1497  |Val Acc:96.4500
# Task1  | Epoch: 14  |Train Loss:  0.0026  |Train Acc:100.0000  |Val Loss:  0.1511  |Val Acc:96.4700
# Task1  | Epoch: 15  |Train Loss:  0.0023  |Train Acc:100.0000  |Val Loss:  0.1523  |Val Acc:96.4800
# Task1  | Epoch: 16  |Train Loss:  0.0021  |Train Acc:100.0000  |Val Loss:  0.1535  |Val Acc:96.4700
# Task1  | Epoch: 17  |Train Loss:  0.0019  |Train Acc:100.0000  |Val Loss:  0.1547  |Val Acc:96.5000
# Task1  | Epoch: 18  |Train Loss:  0.0017  |Train Acc:100.0000  |Val Loss:  0.1557  |Val Acc:96.5100
# Task1  | Epoch: 19  |Train Loss:  0.0016  |Train Acc:100.0000  |Val Loss:  0.1567  |Val Acc:96.5300
# Task1  | Epoch: 20  |Train Loss:  0.0014  |Train Acc:100.0000  |Val Loss:  0.1577  |Val Acc:96.5400
# Task1  | Epoch: 21  |Train Loss:  0.0013  |Train Acc:100.0000  |Val Loss:  0.1586  |Val Acc:96.5400
# Task1  | Epoch: 22  |Train Loss:  0.0012  |Train Acc:100.0000  |Val Loss:  0.1595  |Val Acc:96.5400
# Task1  | Epoch: 23  |Train Loss:  0.0012  |Train Acc:100.0000  |Val Loss:  0.1603  |Val Acc:96.5200
# Task1  | Epoch: 24  |Train Loss:  0.0011  |Train Acc:100.0000  |Val Loss:  0.1611  |Val Acc:96.5100
# Task1  | Epoch: 25  |Train Loss:  0.0010  |Train Acc:100.0000  |Val Loss:  0.1618  |Val Acc:96.5100
# Task1  | Epoch: 26  |Train Loss:  0.0010  |Train Acc:100.0000  |Val Loss:  0.1626  |Val Acc:96.5000
# Task1  | Epoch: 27  |Train Loss:  0.0009  |Train Acc:100.0000  |Val Loss:  0.1633  |Val Acc:96.5000
# Task1  | Epoch: 28  |Train Loss:  0.0009  |Train Acc:100.0000  |Val Loss:  0.1639  |Val Acc:96.5000
# Task1  | Epoch: 29  |Train Loss:  0.0008  |Train Acc:100.0000  |Val Loss:  0.1646  |Val Acc:96.5100
# Task1  | Epoch: 30  |Train Loss:  0.0008  |Train Acc:100.0000  |Val Loss:  0.1652  |Val Acc:96.5100
# Task1  | Epoch: 31  |Train Loss:  0.0008  |Train Acc:100.0000  |Val Loss:  0.1658  |Val Acc:96.5000
# Task1  | Epoch: 32  |Train Loss:  0.0007  |Train Acc:100.0000  |Val Loss:  0.1664  |Val Acc:96.5000
# Task1  | Epoch: 33  |Train Loss:  0.0007  |Train Acc:100.0000  |Val Loss:  0.1669  |Val Acc:96.5000
# Task1  | Epoch: 34  |Train Loss:  0.0007  |Train Acc:100.0000  |Val Loss:  0.1675  |Val Acc:96.4900
# Task1  | Epoch: 35  |Train Loss:  0.0006  |Train Acc:100.0000  |Val Loss:  0.1680  |Val Acc:96.4800
# Task1  | Epoch: 36  |Train Loss:  0.0006  |Train Acc:100.0000  |Val Loss:  0.1685  |Val Acc:96.4800
# Task1  | Epoch: 37  |Train Loss:  0.0006  |Train Acc:100.0000  |Val Loss:  0.1690  |Val Acc:96.4800
# Task1  | Epoch: 38  |Train Loss:  0.0006  |Train Acc:100.0000  |Val Loss:  0.1695  |Val Acc:96.4800
# Task1  | Epoch: 39  |Train Loss:  0.0006  |Train Acc:100.0000  |Val Loss:  0.1700  |Val Acc:96.4700
# Task1  | Epoch: 40  |Train Loss:  0.0005  |Train Acc:100.0000  |Val Loss:  0.1704  |Val Acc:96.4600

# %%
f = open("output.txt", "w")
print('Task1  | Epoch:%3d'%epoch, ' |Train Loss:%8.4f'%(total_train_loss/train_batch_num), ' |Train Acc:%3.4f'%(train_hit/(train_image_num-val_image_num)*100.0)
          , ' |Val Loss:%8.4f'%(total_val_loss/val_batch_num), ' |Val Acc:%3.4f'%(val_hit/val_image_num*100.0), file = f)
f.close()

# %% [markdown]
# ## Dump for evaluation (upload your DL-test-predict.csv to kaggle )

# %%
test_pred_list = []
total_test = 0
for tit in range(test_image_num//Batch_size):
    pred, _ = net.forward(test_data[tit*Batch_size:(tit+1)*Batch_size], train_label_onehot[tit*Batch_size:(tit+1)*Batch_size])
    pred_index = np.argmax(pred, axis=1)
    test_pred_list += pred_index.tolist()
    total_test += Batch_size

print('Please make sure that total test images = 10000')
print(f'Total test images: {total_test} ')

print('Dump file...')
df = pd.DataFrame(test_pred_list, columns=["Category"])
df.to_csv('DL-test-predict.csv', index=True, index_label="Id")
# Out:
# Please make sure that total test images = 10000
# Total test images: 10000
# Dump file...

# %%
# !zip -r DL_Lab1.zip model /content/drive/MyDrive/Colab Notebooks/Lab1_task1_313510164.ipynb DL-test-predict.csv
# Out:
# 	zip warning: name not matched: /content/drive/MyDrive/Colab
# 	zip warning: name not matched: Notebooks/Lab1_task1_313510164.ipynb
# updating: model/ (stored 0%)
# updating: model/__pycache__/ (stored 0%)
# updating: model/__pycache__/__init__.cpython-310.pyc (deflated 20%)
# updating: model/__pycache__/network.cpython-310.pyc (deflated 44%)
# updating: model/__pycache__/layer.cpython-310.pyc (deflated 57%)
# updating: model/__init__.py (deflated 21%)
# updating: model/network.py (deflated 69%)
# updating: model/layer.py (deflated 68%)
# updating: DL-test-predict.csv (deflated 61%)
